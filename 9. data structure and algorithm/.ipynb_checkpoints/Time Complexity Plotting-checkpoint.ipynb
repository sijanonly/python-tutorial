# %% [markdown]
# ### Let's observe the complexity of different approach of creating lists

# %%
def append(n):
    # append
    l = []
    for i in range(n):
        l.append(i)

def concatenation(n):
    # concatenation
    l = []
    for i in range(n):
        l = l + [i]

def list_comprehension(n):
    # list comprehension
    l = [i for i in range(n)]

def list_constructor(n):
    # range + list constructor
    l = list(range(n))

# %%
# %matplotlib inline
from matplotlib import pyplot

import timeit
from functools import partial
def plot_time_complexity(fn, min_value, max_value, incr, no_of_tests):
    """
    Plotting time complexity based on given function.
    """
    x = []
    y = []
    for i in range(min_value, max_value, incr):
        N = i
        timer = timeit.Timer(partial(fn, N))
        t = timer.timeit(number=no_of_tests)
        x.append(i)
        y.append(t)
    p1 = pyplot.plot(x, y, 'o', label = fn.__name__)
    pyplot.legend(loc='upper left')
    pyplot.xlabel('data size', fontsize=18)
    pyplot.ylabel('execution time', fontsize=16)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-cebd3ef95c3b> in <module>()
# ----> 1 get_ipython().magic('matplotlib inline')
#       2 from matplotlib import pyplot
#       3
#       4 import timeit
#       5 from functools import partial
#
# /home/leapfrong/workspace/envs/envtutorial/lib/python3.5/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# /home/leapfrong/workspace/envs/envtutorial/lib/python3.5/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# <decorator-gen-104> in matplotlib(self, line)
#
# /home/leapfrong/workspace/envs/envtutorial/lib/python3.5/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /home/leapfrong/workspace/envs/envtutorial/lib/python3.5/site-packages/IPython/core/magics/pylab.py in matplotlib(self, line)
#      98             print("Available matplotlib backends: %s" % backends_list)
#      99         else:
# --> 100             gui, backend = self.shell.enable_matplotlib(args.gui)
#     101             self._show_matplotlib_backend(args.gui, backend)
#     102
#
# /home/leapfrong/workspace/envs/envtutorial/lib/python3.5/site-packages/IPython/core/interactiveshell.py in enable_matplotlib(self, gui)
#    2935         """
#    2936         from IPython.core import pylabtools as pt
# -> 2937         gui, backend = pt.find_gui_and_backend(gui, self.pylab_gui_select)
#    2938
#    2939         if gui != 'inline':
#
# /home/leapfrong/workspace/envs/envtutorial/lib/python3.5/site-packages/IPython/core/pylabtools.py in find_gui_and_backend(gui, gui_select)
#     270     """
#     271
# --> 272     import matplotlib
#     273
#     274     if gui and gui != 'auto':
#
# ImportError: No module named 'matplotlib'

# %%
plot_time_complexity(append, 1, 100, 1, 1000)
plot_time_complexity(concatenation, 1, 100, 1, 1000)
plot_time_complexity(list_comprehension, 1, 100, 1, 1000)
plot_time_complexity(list_constructor, 1, 100, 1, 1000)
